# %% [markdown]
# # <center> **LISTA DE EXERCÍCIOS 1**
#
# <center>Jefferson dos Santos Leocadio - 20210094044<br>
# Disciplina: DCA0200 - INTELIGÊNCIA ARTIFICIAL - T01 (2022.2 - 35M34)<br>
# Professor: ADRIÃO DUARTE DÓRIA NETO<br>
# Data: 22 de setembro de 2022
#
# **QUESTÃO 1**: A tabela de dados abaixo ilustra a aplicação do método Naïve-Bayes. Um
# determinado banco deve decidir se um cliente deve ou não receber um empréstimo bancário
# em função da sua condição de bom ou mau pagador. Considerando os dados de treinamento
# abaixo, aplique o classificador Naive-Bayes, para atribuir a classe (rótulo) para os registros
# 12 e 13:

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th>
#       Registro
#     <th>
#       Casa Própria
#     <th>
#       Estado Civil
#     <th>
#       Possui Carro
#     <th>
#       Rendimentos
#     <th>
#       Bom Pagador
#   <tr>
#     <td>
#       1
#     <td>
#       Sim
#     <td>
#       Solteiro
#     <td>
#       Sim
#     <td>
#       Alto
#     <td>
#       Não
#   <tr>
#     <td>
#       3
#     <td>
#       Não
#     <td>
#       Solteiro
#     <td>
#       Não
#     <td>
#       Baixo
#     <td>
#       Não
#   <tr>
#     <td>
#       4
#     <td>
#       Sim
#     <td>
#       Casado
#     <td>
#       Sim
#     <td>
#       Alto
#     <td>
#       Não
#   <tr>
#     <td>
#       5
#     <td>
#       Não
#     <td>
#       Divorciado
#     <td>
#       Não
#     <td>
#       Médio
#     <td>
#       Sim
#   <tr>
#     <td>
#       6
#     <td>
#       Não
#     <td>
#       Solteiro
#     <td>
#       Não
#     <td>
#       Baixo
#     <td>
#       Não
#   <tr>
#     <td>
#       7
#     <td>
#       Sim
#     <td>
#       Casado
#     <td>
#       Sim
#     <td>
#       Alto
#     <td>
#       Sim
#   <tr>
#     <td>
#       8
#     <td>
#       Não
#     <td>
#       Solteiro
#     <td>
#       Sim
#     <td>
#       Médio
#     <td>
#       Sim
#   <tr>
#     <td>
#       9
#     <td>
#       Não
#     <td>
#       Casado
#     <td>
#       Sim
#     <td>
#       Baixo
#     <td>
#       Não
#   <tr>
#     <td>
#       10
#     <td>
#       Não
#     <td>
#       Solteiro
#     <td>
#       Não
#     <td>
#       Médio
#     <td>
#       Sim
#   <tr>
#     <td>
#       11
#     <td>
#       Sim
#     <td>
#       Divorciado
#     <td>
#       Não
#     <td>
#       Médio
#     <td>
#       Não
#   <tr>
#     <td>
#       12
#     <td>
#       Não
#     <td>
#       Divorciado
#     <td>
#       Sim
#     <td>
#       Alto
#     <td>
#       ?
#   <tr>
#     <td>
#       13
#     <td>
#       Sim
#     <td>
#       Solteiro
#     <td>
#       Não
#     <td>
#       Médio
#     <td>
#       ?

# %% [markdown]
# O primeiro passo é calcular a tabela de probabilidades. Por questões de organização, utilizou-se as seguintes abreviações: CP = Casa Própria, EC = Estado Civil, PC = Possui Carro, R = Rendimentos e BP = Bom Pagador.
#
# **Tabela de probabilidades**
#
# * P(CP = Sim) = 4/11
# * P(CP = Não) = 7/11
# * P(EC= Solteiro) = 4/11
# * P(EC = Casado) = 4/11
# * P(EC = Divorciado) = 3/11
# * P(EC = Divorciado) = 3/11
# * P(PC = Não) = 5/11
# * P(R = Alto) = 3/11
# * P(R = Médio) = 5/11
# * P(R = Baixo) = 3/11
# * P(BP = Sim) = 4/11
# * P(BP = Não) = 7/11
# * P(CP =Sim | BP = Sim) = 1/4
# * P(CP = Sim | BP = Não) = 3/7
# * P(CP =Não | BP = Sim) = 3/4
# * P(CP = Não | BP = Não) = 4/7
# * P(PC =Sim | BP = Sim) = 2/4
# * P(PC = Sim | BP = Não) = 4/7
# * P(PC =Não | BP = Sim) = 2/4
# * P(PC = Não | BP = Não) = 3/7
# * P(EC = Solteiro | BP = Sim) = 2/4
# * P(EC = Solteiro | BP = Não) = 2/7
# * P(EC = Divorciado | BP = Sim) = 2/4
# * P(EC = Divorciado | BP = Não) = 1/7
# * P(R = Alto | BP = Sim) = 1/4
# * P(R = Alto | BP = Não) = 2/7
# * P(R = Médio | BP = Sim) = 1/4
# * P(R = Médio | BP = Não) = 2/7

# %% [markdown]
# A seguir, precisa-se calcular a probabilidade dos registros 12 e 13 serem bons
# pagadores ou não a partir do teorema de Naive Bayes, o qual é descrito pela seguinte equação:
#
# $$P(H|E) = \frac{P(E_1|H)·P(E_2|H)·...·P(E_n|H)}{P(E_1)·P(E_2)·...·P(E_n)} (1)$$
#
# Assim, para o registro 12, primeiro calculou-se a probabilidade de ser um bom
# pagador (BP), dado que ele não possui casa própria (CP), o estado civil (EC) é divorciado, possui carro (PC) e tem um rendimento (R) alto. Portanto:
#
# $$P_{12s} = P(BP = Sim | CP = Não, EC = Divorciado, PC = Sim, R = Alto)$$
#
# $$P_{12s} = \frac{𝑃(𝐶𝑃=𝑁|𝐵𝑃=𝑆)·𝑃(𝐸𝐶=𝐷|𝐵𝑃=𝑆)·𝑃(𝑃𝐶=𝑆|𝐵𝑃=𝑆)·𝑃(𝑅=𝐴|𝐵𝑃=𝑆)·𝑃(𝐵𝑃=𝑆)}{𝑃(𝐶𝑃=𝑁)·𝑃(𝐸𝐶=𝐷)·𝑃(𝑃𝐶=𝑆)·𝑃(𝑅=𝐴)}$$
#
# $$P_{12s} = \frac{\frac{3}{4}·\frac{2}{4}·\frac{2}{4}·\frac{1}{4}·\frac{4}{11}}{\frac{7}{11}·\frac{3}{11}·\frac{6}{11}·\frac{3}{11}} = 0.6602 \approx 66\% $$
#
# A seguir, calculou-se a probabilidade de não ser um bom pagador dadas as mesmas
# características:
#
# $$P_{12s} = 𝑃(𝐵𝑃 = 𝑁ã𝑜|𝐶𝑃 = 𝑁ã𝑜, 𝐸𝐶 = 𝐷𝑖𝑣𝑜𝑟𝑐𝑖𝑎𝑑𝑜, 𝑃𝐶 = 𝑆𝑖𝑚, 𝑅 = 𝐴𝑙𝑡𝑜)$$
#
# $$P_{12s} = \frac{𝑃(𝐶𝑃=𝑁|𝐵𝑃=𝑁)·𝑃(𝐸𝐶=𝐷|𝐵𝑃=𝑁)·𝑃(𝑃𝐶=𝑆|𝐵𝑃=𝑁)·𝑃(𝑅=𝐴|𝐵𝑃=𝑁)·𝑃(𝐵𝑃=𝑁)}{𝑃(𝐶𝑃=𝑁)·𝑃(𝐸𝐶=𝐷)·𝑃(𝑃𝐶=𝑆)·𝑃(𝑅=𝐴)}$$
#
# $$P_{12s} = \frac{\frac{4}{7}·\frac{1}{7}·\frac{4}{7}·\frac{2}{7}·\frac{7}{11}}{\frac{7}{11}·\frac{3}{11}·\frac{6}{11}·\frac{3}{11}} = 0.3285 = 32.85\% $$
#
# Como $P_{12S}$ > $P_{12N}$, o cliente 12 é considerado um bom pagador pelo algoritmo Naive Bayes.

# %% [markdown]
# A seguir calculou-se a probabilidade de ser um bom pagador (BP) para o registro 13, dado que ele possui casa própria (CP), o estado civil (EC) é Solteiro, não possui carro (PC) e tem um rendimento (R) Médio. Portanto:
#
# $$P_{13S} = 𝑃(𝐵𝑃 = 𝑆𝑖𝑚|𝐶𝑃 = 𝑆𝑖𝑚, 𝐸𝐶 = 𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜, 𝑃𝐶 = 𝑁ã𝑜, 𝑅 = 𝑀é𝑑𝑖𝑜)$$
#
# $$P_{13S} = \frac{𝑃(𝐶𝑃=𝑆|𝐵𝑃=𝑆)·𝑃(𝐸𝐶=𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜|𝐵𝑃=𝑆)·𝑃(𝑃𝐶=𝑁|𝐵𝑃=𝑆)·𝑃(𝑅=𝑀|𝐵𝑃=𝑆)·𝑃(𝐵𝑃=𝑆)}{𝑃(𝐶𝑃=𝑆)·𝑃(𝐸𝐶=𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜)·𝑃(𝑃𝐶=𝑁)·𝑃(𝑅=𝑀)}$$
#
# $$P_{13S} = \frac{\frac{1}{4}·\frac{2}{4}·\frac{2}{4}·\frac{3}{4}·\frac{4}{11}}{\frac{4}{11}·\frac{4}{11}·\frac{5}{11}·\frac{5}{11}} = 0.6239 = 62.39\%$$
#
# A seguir, calculou-se a probabilidade de não ser um bom pagador dadas as mesmas
# características:
#
# $$P_{13N} = 𝑃(𝐵𝑃 = 𝑆𝑖𝑚|𝐶𝑃 = 𝑆𝑖𝑚, 𝐸𝐶 = 𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜, 𝑃𝐶 = 𝑁ã𝑜, 𝑅 = 𝑀é𝑑𝑖𝑜)$$
#
# $$P_{13N} = \frac{𝑃(𝐶𝑃=𝑆|𝐵𝑃=𝑁)·𝑃(𝐸𝐶=𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜|𝐵𝑃=𝑁)·𝑃(𝑃𝐶=𝑁|𝐵𝑃=𝑁)·𝑃(𝑅=𝑀|𝐵𝑃=𝑁)·𝑃(𝐵𝑃=𝑁)}{𝑃(𝐶𝑃=𝑆)·𝑃(𝐸𝐶=𝑆𝑜𝑙𝑡𝑒𝑖𝑟𝑜)·𝑃(𝑃𝐶=𝑁)·𝑃(𝑅=𝑀)}$$
#
# $$P_{13N} = \frac{\frac{3}{7}·\frac{2}{7}·\frac{3}{7}·\frac{2}{7}·\frac{7}{11}}{\frac{4}{11}·\frac{4}{11}·\frac{5}{11}·\frac{5}{11}} = 0.3492 = 34.92\%$$
#
# Como $P_{12S} > P_{12N}$, o cliente 13 também é considerado um bom pagador pelo algoritmo Naive Bayes.

# %% [markdown]
# **QUESTÃO 2:** A rede bayesiana abaixo concerne ao problema de partida de um carro, de uma forma bem simplificada (Extraído do Livro Bayesian Reasoning and Machine Learning - D. Barber).
#
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Foram consideradas as seguintes abreviações: b = battery, g = gauge, f = fuel, t = turn over, s = start, fa = false, tr = true. As probabilidades referentes a rede bayesiana são dadas por:
# $\alpha$
# <center>
# <table>
#   <tr>
#     <td>
#       $p(b=bad)=0.05$
#     <td>
#       $p(f=empty)=0.1$
#     <tr>
#     <td>
#       $p(g=empty|b=good,f=not empty)=0.05$
#     <td>
#       $p(g=empty|b=good,f=empty)=0.98$
#     <tr>
#     <td>
#       $p(g=empty|b=bad,f=not empty)=0.07$
#     <td>
#       $p(g=empty|b=bad,f=empty)=0.97$
#     <tr>
#     <td>
#       $p(t=fa|b=good)=0.1$
#     <td>
#       $p(t=fa|b=bad)=0.96$
#     <tr>
#     <td>
#       $p(s=fa|t=tr, f=not empty)=0.01$
#     <td>
#       $p(s=fa|t=tr, f=empty)=0.92$
#     <tr>
#     <td>
#       $p(s=fa|t=fa, f=not empty)=1.0$
#     <td>
#       $p(s=fa|t=fa, f=empty)=0.99$

# %% [markdown]
# Um agente inteligente com base nas inferências, isto é, o cálculo da P(f=empty|s=no) (a probabilidade do tanque estar vazio dado que o carro não deu partida) e da P(b=bad|s=no) (a probabilidade da bateria estar descarregada e o carro não deu partida), deve decidir qual o problema mais provável pela não partida do carro. Apresente a solução e implemente os cálculos de forma computacional.
#
#
# Analisando o gráfico da rede bayesiana, pode tirar as seguintes conclusões:
# * Battery (b) não é filho de ninguém;
# * Fuel (f) não é filho de ninguém
# * Gauge (g) é filho de Battery (b) e Fuel (f)
# * Turn Over (t) é filho de Battery (b)
# * Start (s) é filho de Fuel (f)
#
# De forma matemática, queremos calcular $P(f=empty|s=fa)$. Assim, pela propriedade
# da independência condicional, que pela condição de Markov, podemos calcular a distribuição de probabilidade conjunta sobre todas as variáveis X1, X2
# , …, Xn da rede bayesiana através da seguinte fórmula:
#
# $$P(X_1, X_2, ..., X_n) = \Pi_{i=1}^{n}P(X_i| Pais(x_i)) (2)$$
#
# Assim, aplicando ao contexto da questão:
#
# $$𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦|𝑠 = 𝑓𝑎) = \frac{𝑃(𝑓=𝑒𝑚𝑝𝑡𝑦,𝑠=𝑓𝑎)}{𝑃(𝑠=𝑓𝑎)} = \frac{𝑃(𝑓=𝑒𝑚𝑝𝑡𝑦)·𝑃(𝑠=𝑓𝑎|𝑓=𝑒𝑚𝑝𝑡𝑦,𝑡)}{𝑃(𝑠=𝑓𝑎)}(2.1)$$
#
# Calculando $P(s=fa | empty, t)$:
#
# $$𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡) = 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑡𝑟) · 𝑃(𝑡 = 𝑡𝑟|𝑏) + 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑓𝑎) · 𝑃(𝑡 = 𝑓𝑎|𝑏) (2.2)$$
#
# Mas não se conhece o valor de $P(t = tr | b)$ e $P(t = fa | b)$, assim
# $𝑃(𝑡 = 𝑡𝑟|𝑏) = 𝑃(𝑡 = 𝑓𝑎|𝑏 = 𝑏𝑎𝑑) · 𝑃(𝑏 = 𝑏𝑎𝑑) + 𝑃(𝑡 = 𝑓𝑎|𝑏 = 𝑔𝑜𝑜𝑑) · 𝑃(𝑏 = 𝑔𝑜𝑜𝑑)$
#
# $𝑃(𝑡 = 𝑡𝑟|𝑏) = 0. 96 · 0. 05 + 0. 1 · (1 − 0. 5) = 0. 143$
#
# Assim, $𝑃(𝑡 = 𝑓𝑎|𝑏) = 1 − 0. 143 = 0. 857$
#
# Substituindo os valores na equação 2.2,
# $𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡) = 0. 92 · 0. 857 + 0. 99 · 0. 143 = 0.93001$
#
# Da equação 2.1, não se conhece o valor de $P(s=fa)$, o qual pode ser encontrado através da seguinte equação:
#
# $𝑃(𝑠 = 𝑓𝑎) = 𝑃(𝑠 = 𝑓𝑎| 𝑓, 𝑡)$
# $𝑃(𝑠 = 𝑓𝑎) = 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑓𝑎) · 𝑃(𝑡 = 𝑓𝑎|𝑏) · 𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑡𝑟) · 𝑃(𝑡 = 𝑡𝑟|𝑏) · 𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑓𝑎) · 𝑃(𝑡 = 𝑓𝑎|𝑏) · 𝑃(𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑡𝑟) · 𝑃(𝑡 = 𝑡𝑟|𝑏) · 𝑃(𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦)$
#
# Substituindo os valores, temos:
#
# $𝑃(𝑠 = 𝑓𝑎) = 0. 99 · 0. 1 · 0. 143 + 0. 92 · 0. 1 · 0. 857 +
# 1 · 0. 9 · 0. 143 + 0. 01 · 0. 9 · 0. 857$
# $𝑃(𝑠 = 𝑓𝑎) = 0. 2294$
#
# Como todos os valores foram encontrados, pode-se calcular o resultado da equação 2.1
#
# $$𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦|𝑠 = 𝑓𝑎) = \frac{𝑃(𝑓=𝑒𝑚𝑝𝑡𝑦)·𝑃(𝑠=𝑓𝑎|𝑓=𝑒𝑚𝑝𝑡𝑦,𝑡)}{𝑃(𝑠=𝑓𝑎)} = \frac{0.1·0.93001}{0.2294} = 0.4054$$
#
# A seguir, irá se calcular a outra probabilidade requisitada pela questão:
#
# $$𝑃(𝑏 = 𝑏𝑎𝑑|𝑠 = 𝑓𝑎) = \frac{𝑃(𝑏=𝑏𝑎𝑑, 𝑠=𝑓𝑎)}{𝑃(𝑠=𝑓𝑎)} = \frac{𝑃(𝑏=𝑏𝑎𝑑)·𝑃(𝑠=𝑓𝑎| 𝑓, 𝑡)}{𝑃(𝑠=𝑓𝑎)}(2.3)$$
#
# Para isso, precisa-se calcular o valor de $𝑃(𝑠 = 𝑓𝑎| 𝑓, 𝑡)$. Assim,
#
# $𝑃(𝑠 = 𝑓𝑎| 𝑓, 𝑡) = 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑡𝑟) · 𝑃(𝑡 = 𝑡𝑟|𝑏 = 𝑏𝑎𝑑) · 𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑓𝑎) · 𝑃(𝑡 = 𝑓𝑎|𝑏 = 𝑏𝑎𝑑) · 𝑃(𝑓 = 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑡𝑟) · 𝑃(𝑡 = 𝑡𝑟|𝑏 = 𝑏𝑎𝑑) · 𝑃(𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦) +
# 𝑃(𝑠 = 𝑓𝑎|𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦, 𝑡 = 𝑓𝑎) · 𝑃(𝑡 = 𝑓𝑎|𝑏 = 𝑏𝑎𝑑) · 𝑃(𝑓 = 𝑛𝑜𝑡 𝑒𝑚𝑝𝑡𝑦)
# $
#
# Como todas as probabilidades acima são conhecidas, pode-se substituir e encontrar o resultado.
#
# $𝑃(𝑠 = 𝑓𝑎| 𝑓, 𝑡) = 0. 92 · 0. 1 · (1 − 0. 96) + 0. 99 · 0. 1 · 0. 96 + 0. 01 · 0. 9 · (1 − 0. 96) + 1 · 0. 9 · 0. 96$
#
# $𝑃(𝑠 = 𝑓𝑎| 𝑓, 𝑡) = 0. 96308$
#
# Substituindo os valores na equação 2.3,
#
# $𝑃(𝑏 = 𝑏𝑎𝑑|𝑠 = 𝑓𝑎) = \frac{𝑃(𝑏=𝑏𝑎𝑑)·𝑃(𝑠=𝑓𝑎| 𝑓, 𝑡)}{𝑃(𝑠=𝑓𝑎)} = \frac{0.05·0.96308}{0.2294} = 0.2099$

# %% [markdown]
# **QUESTÃO 3:** Uma rede de crença (ou rede bayesiana), modela a relação entre as variáveis: oil (price of oil), inf (inflation) , eh (economy health), bp (British Petroleum Stock price), rt(retailer stock price). Cada variável tem dois estados (l:low) e (h:high), exceto a variável bp
# que tem adicionalmente o estado (n: normal). A rede de crença modela as variáveis de acordo com a tabela abaixo. (Extraído do Livro Bayesian Reasoning and Machine Learning - D.Barber)

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th colspan="2">
#       eh(economy health)
#   <tr>
#     <td>
#       P(eh=low)
#     <td>
#       P(eh=high)
#   <tr>
#     <td>
#       0.7
#     <td>
#       0.3

# %% [markdown]
# <center>
# <table>
#   <th colspan="3">
#     oil(price of oil)
#   <tr>
#     <td>
#       eh
#     <td>
#       oil=low
#     <td>
#       oil=high
#   <tr>
#     <td>
#       low
#     <td>
#       0.9
#     <td>
#       0.1
#   <tr>
#     <td>
#       high
#     <td>
#       0.05
#     <td>
#       0.95

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th colspan="4">
#       bp(British petroleum stock price)
#   <tr>
#     <td>
#       oil
#     <td>
#       bp=low
#     <td>
#       bp=high
#     <td>
#       bp=normal
#   <tr>
#     <td>
#       low
#     <td>
#       0.9
#     <td>
#       0
#     <td>
#       0.1
#   <tr>
#     <td>
#       high
#     <td>
#       0.1
#     <td>
#       0.5
#     <td>
#       0.4

# %% [markdown]
# <center>
# <table>
# <tr>
# <th colspan="4">
# rt(retailer stock price)
# <tr>
# <td>
# inf
# <td>
# eh
# <td>
# rt=low
# <td>
# rt=high
# <tr>
# <td>
# low
# <td>
# low
# <td>
# 0.9
# <td>
# 0.1
# <tr>
# <td>
# low
# <td>
# high
# <td>
# 0.1
# <td>
# 0.9
# <tr>
# <td>
# high
# <td>
# low
# <td>
# 0.1
# <td>
# 0.9
# <tr>
# <td>
# high
# <td>
# high
# <td>
# 0.01
# <td>
# 0.99

# %% [markdown]
# <center>
# <table>
# <tr>
# <th colspan="4">
# inf(inflation)
# <tr>
# <td>
# oil
# <td>
# eh
# <td>
# rt=low
# <td>
# rt=high
# <tr>
# <td>
# low
# <td>
# low
# <td>
# 0.9
# <td>
# 0.1
# <tr>
# <td>
# low
# <td>
# high
# <td>
# 0.1
# <td>
# 0.9
# <tr>
# <td>
# high
# <td>
# low
# <td>
# 0.1
# <td>
# 0.9
# <tr>
# <td>
# high
# <td>
# high
# <td>
# 0.01
# <td>
# 0.99

# %% [markdown]
# a) Determine o gráfico da rede de crença (rede bayesiana) para este problema.
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) Dado que a bp=n e rt=h, qual é a probabilidade de que a inflação seja alta?
#
# Escrevendo de forma matemática,
#
# $𝑃(𝑖𝑛𝑓 = ℎ|𝑏𝑝 = 𝑛, 𝑟𝑡 = ℎ) = \frac{𝑃(𝑖𝑛𝑓=ℎ, 𝑏𝑝=𝑛, 𝑟𝑡=ℎ}{𝑃(𝑏𝑝=𝑛, 𝑟𝑡=ℎ𝑖)} = \frac{𝑃(𝑖𝑛𝑓=ℎ|𝑒ℎ,𝑜𝑖𝑙)·𝑃(𝑏𝑝=𝑛|𝑜𝑖𝑙)·𝑃( 𝑟𝑡=ℎ|𝑒ℎ,𝑖𝑛𝑓=ℎ)}{𝑃(𝑏𝑝=𝑛, 𝑟𝑡=ℎ𝑖)} (3.1)$
#
# Calculando $P(inf = h | eh, oil)$,
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ, 𝑜𝑖𝑙) = 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑒ℎ = 𝑙) · 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = 𝑙) +
# 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙 = ℎ) · 𝑃(𝑒ℎ = ℎ) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = ℎ) +
# 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙 = ℎ) · 𝑃(𝑒ℎ = 𝑙) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = 𝑙) + 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑒ℎ = ℎ) · 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = ℎ)$$
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ, 𝑜𝑖𝑙) = 0.1 · 0.7 · 0.9 + 0.99 · 0.3 · 0.95 +
# 0.9 · 0.7 · 0.1 + 0.9 · 0.3 · 0.05 =  0.42165$$
#
# Calculando $P(bp=n| oil)$,
#
# $$𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) = 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = ℎ) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ) + 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑏𝑝 = 𝑙|𝑒ℎ)$$
#
# $$𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) = 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = ℎ) · [𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = 𝑙) · 𝑃(𝑒ℎ = 𝑙) +
# 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = ℎ) · 𝑃(𝑒ℎ = ℎ)] +
# 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = 𝑙) · [𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = 𝑙) · 𝑃(𝑒ℎ = 𝑙) +
# 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = ℎ) · 𝑃(𝑒ℎ = ℎ)]$$
#
# $$𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) = 0. 4 · [0. 1 · 0. 7 + 0. 95 · 0. 3] + 0. 1 · [0. 9 · 0. 7 + 0. 05 · 0. 3] = 0. 2065$$
#
# Calculando $P(rt=h | eh, inf=h)$ equação (3.2),
#
# $$𝑃( 𝑟𝑡 = ℎ|𝑒ℎ, 𝑖𝑛𝑓 = ℎ) = 𝑃(𝑟𝑡 = ℎ|𝑖𝑛𝑓 = ℎ, 𝑒ℎ = 𝑙) · 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙) · 𝑃(𝑒ℎ = 𝑙) +
# 𝑃(𝑟𝑡 = ℎ|𝑖𝑛𝑓 = ℎ, 𝑒ℎ = ℎ) · 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙) · 𝑃(𝑒ℎ = ℎ)$$
#
# Para calcular o resultado da equação acima, precisa-se das probabilidades $P(inf = h |
# eh = l, oil)$ e $P(inf = h | eh = h, oil)$, as quais podem ser calculadas a partir das seguintes
# equações.
#
# Para a primeira probabilidade,
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙) = 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = 𝑙) · 𝑃(𝑒ℎ = 𝑙) +
# 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙 = ℎ) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = 𝑙) · 𝑃(𝑒ℎ = 𝑙)$$
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙) = 0. 1 · 0. 9 · 0. 7 + 0. 9 · 0. 1 · 0. 7 = 0. 126$$
#
# Para a segunda,
#
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙) = 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙 = ℎ) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ = ℎ) · 𝑃(𝑒ℎ = ℎ) +
# 𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = ℎ, 𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ = ℎ) · 𝑃(𝑒ℎ = ℎ)$$
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑒ℎ = 𝑙, 𝑜𝑖𝑙) = 0. 99 · 0. 95 · 0. 3 + 0. 9 · 0. 05 · 0. 3 = 0. 29565$$
#
# Substituindo de volta na equação 3.2, temos que:
#
# $$𝑃( 𝑟𝑡 = ℎ|𝑒ℎ, 𝑖𝑛𝑓 = ℎ) = 0. 9 · 0. 126 · 0. 7 + 0. 99 · 0. 29565 · 0. 3 = 0. 1672$$
#
# Por fim, precisa-se calcular a probabilidade do denominador da equação 3, a qual está descrita a seguir:
#
# $$𝑃(𝑏𝑝 = 𝑛, 𝑟𝑡 = ℎ𝑖) = 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) · 𝑃(𝑟𝑡 = ℎ|𝑖𝑛𝑓, 𝑒ℎ)$$
#
# Assim, calculando primeiramente $P(bp = n | oil)$,
#
# $$𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) = 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = 𝑙) · 𝑃(𝑜𝑖𝑙 = 𝑙|𝑒ℎ) + 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙 = ℎ) · 𝑃(𝑜𝑖𝑙 = ℎ|𝑒ℎ)
# 𝑃(𝑏𝑝 = 𝑛|𝑜𝑖𝑙) = 0. 2065$$
#
# A seguir, calculando $P(rt = h | inf, eh)$,
#
# $$𝑃(𝑟𝑡 = ℎ|𝑖𝑛𝑓, 𝑒ℎ) = 0. 1 · 0. 7 · (1 − 0. 126) + 0. 9 · 0. 3 · (1 − 0. 29565) + 0. 9 · 0. 7 · 0. 126 + 0. 99 · 0. 3 · 0. 29565 = 0. 4185
# $$
#
# Assim, substituindo todos os valores na equação 3,
#
#
# $$𝑃(𝑖𝑛𝑓 = ℎ|𝑏𝑝 = 𝑛, 𝑟𝑡 = ℎ) = \frac{0.42165·0.2065·0.1672}{0.2065·0.4185} = 0. 1685$$

# %% [markdown]
# **QUESTÃO 4**: Considere o problema de tomada de decisão caracterizado por uma sequência de eventos que podem ser apresentado por um grafo conhecido como rede de decisão. O problema em questão consiste das escolhas e das decisões por parte de uma empresa de petróleo. Uma determinada empresa petrolífera obteve a concessão para explorar uma certa região. Os estudos anteriores (testes preliminares) estimam a probabilidade de existir petróleo nessa região em 30 %. A companhia pode optar por um novo teste, que custa US\$ 100.000,00, sendo que, se realmente existe petróleo, esse teste dirá com uma probabilidade de
# 0.85 que existe, e se realmente não existe, dirá com probabilidade 0.75 que não existe. Considerando que o custo de perfuração será de US\$ 1.000.000,00 e que, se for encontrado petróleo, a companhia receberá US$ 20.000.000,00 pela produção. Considere, portanto os
# seguintes eventos e os seus complementos: (i) Evento T (a companhia faz o teste); (ii) Evento F (o teste é favorável à existência de petróleo; (iii) Evento P (a companhia perfura o poço); (iv) Evento E (existe petróleo).
#
# a) Construa a rede indicando os nós de decisões e os nós ao acaso (variáveis aleatórias). Considere as funções de utilidade, representadas por losangos, como sendo o lucro =receita - despesas, calculado em cada percurso da árvore.
#
# b) Determine em cada nó dos percursos da árvore a utilidade esperada.
#
# c) Usando o critério da utilidade máxima esperada, determine a melhor decisão.
#
# d) Qual o valor esperado do lucro da companhia se for tomada a melhor decisão?
#
# e) Apresente também a solução deste problema através de um programa computacional e simule diferentes situações alterando o valor das probabilidades.
#
# Observações:
#
# i) O evento inicial da árvore é se a companhia faz ou não faz o teste.
#
# ii) Para cada evento tem o seu complementar: Exemplo: T: Faz o teste, ⌐T: Não faz o teste
#
# iii) Para o cálculo da utilidade esperada determine antes as probabilidades condicionais a posteriori com base no teorema de Bayes.

# %% [markdown]
# **Resposta**: O primeiro passo para a montagem da rede de decisão é realizar os cálculos
# das probabilidades de cada nó. Assim, determinando a probabilidade de haver ou não petróleo:
#
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚) = 0. 3$$
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑁ã𝑜) = 0. 7$$
#
# Determinando a probabilidade de quando um novo é realizado.
#
# $$𝑃(𝑛𝑡 = 𝑆𝑖𝑚 | 𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚) = 0. 85$$
# $$𝑃(𝑛𝑡 = 𝑁ã𝑜 | 𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑁ã𝑜) = 0. 75$$
# $$𝑃(𝑛𝑡 = 𝑁ã𝑜 | 𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚) = 0. 15$$
# $$𝑃(𝑛𝑡 = 𝑆𝑖𝑚 | 𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑁ã𝑜) = 0. 25$$
#
# Uma vez que um novo teste é realizado, é possível calcular a probabilidade do teste ser favorável ou não à existência de petróleo.
#
# $$𝑃(𝑛𝑡 = 𝑆𝑖𝑚) = 𝑃(𝑛𝑡 = 𝑆𝑖𝑚 | 𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜 = 𝑆𝑖𝑚) · 𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜 = 𝑆𝑖𝑚) +
# 𝑃(𝑛𝑡 = 𝑆𝑖𝑚 | 𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜 = 𝑁ã𝑜) · 𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜 = 𝑁ã𝑜)$$
# $$𝑃(𝑛𝑡 = 𝑆𝑖𝑚) = 0. 85 · 0. 3 + 0. 25 · 0. 7 = 0. 43$$
# $$𝑃(𝑛𝑡 = 𝑁ã𝑜) = 1 − 0. 43 = 0. 57$$
#
# Dado o resultado do novo teste, é possível determinar a probabilidade de encontrar ou não petróleo.
#
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚 | 𝑛𝑡 = 𝑆𝑖𝑚) = \frac{𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚,𝑛𝑡=𝑠𝑖𝑚)}{𝑃(𝑛𝑡=𝑆𝑖𝑚)} = \frac{𝑃(𝑛𝑡=𝑆𝑖𝑚 | 𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚)·𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚)}{𝑃(𝑛𝑡=𝑆𝑖𝑚)}$$
#
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚 | 𝑛𝑡 = 𝑆𝑖𝑚) = \frac{0.85·0.3}{0.43} = 0. 593$$
#
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑁ã𝑜 | 𝑛𝑡 = 𝑆𝑖𝑚) = 1 − 𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚 | 𝑛𝑡 = 𝑆𝑖𝑚) = 0. 407$$
#
# $$𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚 | 𝑛𝑡 = 𝑁ã𝑜) = \frac{𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚,𝑛𝑡=𝑁ã𝑜)}{𝑃(𝑛𝑡=𝑁ã𝑜)} = \frac{𝑃(𝑛𝑡=𝑁ã𝑜 | 𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚)·𝑃(𝑝𝑒𝑡𝑟𝑜𝑙𝑒𝑜=𝑆𝑖𝑚)}{𝑃(𝑛𝑡=𝑁ã𝑜)}$$
#
# $$P(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑁ã𝑜 | 𝑛𝑡 = 𝑁ã𝑜) = 𝑃(𝑝𝑒𝑡𝑟ó𝑙𝑒𝑜 = 𝑆𝑖𝑚 | 𝑛𝑡 = 𝑁ã𝑜) = 0. 9211$$
#
# Com as probabilidades calculadas, pode-se montar a árvore de decisão.

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por fim, precisa-se calcular a máxima utilidade esperada para encontrar a melhor decisão que a empresa pode tomar dadas as probabilidades. Para isso, é necessário calcular a utilidade de fazer ou não o teste.
#
# $$𝑈(¬𝑇) = 19. 000. 000 · 0. 3 − 1. 000. 000 · 0. 7 + 0 = 5. 000. 000$$
#
# $$𝑈(𝑇) = 0. 43 · [0. 593 · 18. 900. 000 − 0. 407 · 1. 100. 000 − 100. 000] +
# 0. 57 · [0. 0789 · 18. 900. 000 − 0. 9211 · 1. 100. 000 − 100. 000]$$
#
# $$𝑈(𝑇) = 4. 799. 260$$
#
# Assim, a melhor decisão é não fazer o teste, havendo uma recompensa ao final de 5.000.000.

# %% [markdown]
# **QUESTÃO 5**: Considere os dados apresentados na tabela abaixo. Assumindo que as distribuições associadas a cada classe são gaussianas com probabilidades a priori dadas por $(P(\omega_1) = P(\omega_2) = \frac{1}{2}$
# <center>
# <table>
# <tr>
# <th>
# Classe
# <th>
# $\omega_1$
# <th>
# $\omega_2$
# <tr>
# <td>
# Variáveis
# <td>
# $x_1$ $x_2$
# <td>
# $x_1$ $x_2$
# <tr>
# <td>
# 1
# <td>
# -5.01 -8.12
# <td>
# -0.91 -0.18
# <tr>
# <td>
# 2
# <td>
# -5.43 -3.48
# <td>
# 1.30 -2.06
# <tr>
# <td>
# 3
# <td>
# 1.08 -5.52
# <td>
# -7.75 -4.54
# <tr>
# <td>
# 4
# <td>
# 0.86 -3.78
# <td>
# -5.47 0.50
# <tr>
# <td>
# 5
# <td>
# -2.67 0.63
# <td>
# 6.14 5.72
# <tr>
# <td>
# 6
# <td>
# 4.94 3.29
# <td>
# 3.60 1.26
# <tr>
# <td>
# 7
# <td>
# -2.51 2.09
# <td>
# 5.37 -4.63
# <tr>
# <td>
# 8
# <td>
# -2.25 -2.13
# <td>
# 7.18 1.46
# <tr>
# <td>
# 9
# <td>
# 5.56 2.86
# <td>
# -7.39 1.17
# <tr>
# <td>
# 10
# <td>
# 1.03 -3.33
# <td>
# -7.50 -6.32
# </table>
#
# a) Estime o vetor média e a matriz de covariância de cada distribuição gaussiana multivariada.

# %%
import numpy as np

# %%
w1_x1 = [-5.01,-5.43,1.08,0.86,-2.67,4.94,-2.51,-2.25,5.56,1.03]
w1_x2 = [-8.12,-3.48,-5.52,-3.78,0.63,3.29,2.09,-2.13,2.86,-3.33]
w2_x1 = [-0.91,1.3,-7.75,-5.47,6.14,3.6,5.37,7.18,-7.39,-7.5]
w2_x2 = [-0.18,-2.06,-4.54,0.5,5.72,1.26,-4.63,1.46,1.17,-6.32]

# %%
# Calculando as médias
avg_w1_x1 = np.mean(w1_x1)
avg_w1_x2 = np.mean(w1_x2)
avg_w2_x1 = np.mean(w2_x1)
avg_w2_x2 = np.mean(w2_x2)

# %%
# Calculando as matrizes de covariância

w1_s11 = 0
w1_s12 = 0
w1_s21 = 0
w1_s22 = 0
for i in range(0,10):
  w1_s11 += (w1_x1[i]-avg_w1_x1)*(w1_x1[i]-avg_w1_x1)
  w1_s12 += (w1_x1[i]-avg_w1_x1)*(w1_x2[i]-avg_w1_x2)
  w1_s21 += (w1_x2[i]-avg_w1_x2)*(w1_x1[i]-avg_w1_x1)
  w1_s22 += (w1_x2[i]-avg_w1_x2)*(w1_x2[i]-avg_w1_x2)

w1_s11 = round(w1_s11/9, 4)
w1_s12 = round(w1_s12/9, 4)
w1_s21 = round(w1_s21/9, 4)
w1_s22 = round(w1_s22/9, 4)

matriz_w1 = [[w1_s11, w1_s12], [w1_s21, w1_s22]]
matriz_w1
# Out:
# [[14.3805, 7.6954], [7.6954, 14.6231]]

# %%
# Calculando as matrizes de covariância

w2_s11 = 0
w2_s12 = 0
w2_s21 = 0
w2_s22 = 0
for i in range(0,10):
  w2_s11 += (w2_x1[i]-avg_w2_x1)*(w2_x1[i]-avg_w2_x1)
  w2_s12 += (w2_x1[i]-avg_w2_x1)*(w2_x2[i]-avg_w2_x2)
  w2_s21 += (w2_x2[i]-avg_w2_x2)*(w2_x1[i]-avg_w2_x1)
  w2_s22 += (w2_x2[i]-avg_w2_x2)*(w2_x2[i]-avg_w2_x2)

w2_s11 = round(w2_s11/9, 4)
w2_s12 = round(w2_s12/9, 4)
w2_s21 = round(w2_s21/9, 4)
w2_s22 = round(w2_s22/9, 4)

matriz_w2 = [[w2_s11, w2_s12], [w2_s21, w2_s22]]
matriz_w2
# Out:
# [[36.8293, 9.9809], [9.9809, 13.1686]]

# %% [markdown]
# b) Determine a superfície de decisão

# %%
avg_w1 = np.asarray([
    [avg_w1_x1],
    [avg_w1_x2]
], dtype='float32')

avg_w2 = np.asarray([
    [avg_w2_x1],
    [avg_w2_x2]
], dtype='float32')

cov_w1 = np.asarray([
    [w1_s11, w1_s12],
    [w1_s21, w1_s22]
], dtype='float32')

cov_w2 = np.asarray([
    [w2_s11, w2_s12],
    [w2_s21, w2_s22]
], dtype='float32')

print(avg_w1)
print(avg_w2)
print(cov_w1)
print(cov_w2)
# Out:
# [[-0.44 ]
#  [-1.749]]
# [[-0.543]
#  [-0.762]]
# [[14.3805  7.6954]
#  [ 7.6954 14.6231]]
# [[36.8293  9.9809]
#  [ 9.9809 13.1686]]

# %%
# Função discriminante g1
def g1(x):
  t1 = np.transpose(x-avg_w1)
  t2 = np.linalg.inv(cov_w1)
  t3 = x-avg_w1
  t4 = np.dot(t1, t2)
  t5 = np.dot(t4, t3)
  t6 = np.log(np.linalg.det(cov_w1))
  r = float(-0.5*t5 - 0.5*t6)
  return round(r,4)

# %%
# Função discriminante g2
def g2(x):
  t1 = np.transpose(x-avg_w2)
  t2 = np.linalg.inv(cov_w2)
  t3 = x-avg_w2
  t4 = np.dot(t1, t2)
  t5 = np.dot(t4, t3)
  t6 = np.log(np.linalg.det(cov_w2))
  r = float(-0.5*t5 - 0.5*t6)
  return round(r,4)

# %% [markdown]
# c) Classifique os pontos (padrões) (1, 2)t , (5, 3)t , (0, 0)t , (1, 0)t , decidindo pela classe com maior valor das funções discriminantes, isto e, max{gi(x)} ou faça pela região definida pela superfície de separação (função descriminante)

# %%
#Ponto (1,2)
ponto1 = np.asarray([
    [1,2]
], dtype='float32')
ponto1 = np.transpose(ponto1)

if g1(ponto1) - g2(ponto1) > 0:
  print("Esse ponto é classificado como classe w1")
else:
  print("Esse ponto é classificado como classe w2")
# Out:
# Esse ponto é classificado como classe w1

# %%
#Ponto (5,3)
ponto2 = np.asarray([
    [5,3]
], dtype='float32')
ponto2 = np.transpose(ponto2)
if g1(ponto2) - g2(ponto2) > 0:
  print("Esse ponto é classificado como classe w1")
else:
  print("Esse ponto é classificado como classe w2")
# Out:
# Esse ponto é classificado como classe w2

# %%
#Ponto (0,0)
ponto3 = np.asarray([
    [0,0]
], dtype='float32')
ponto3 = np.transpose(ponto3)
if g1(ponto3) - g2(ponto3) > 0:
  print("Esse ponto é classificado como classe w1")
else:
  print("Esse ponto é classificado como classe w2")
# Out:
# Esse ponto é classificado como classe w1

# %%
#Ponto (1,0)
ponto4 = np.asarray([
    [1,0]
], dtype='float32')
ponto4 = np.transpose(ponto4)
if g1(ponto4) - g2(ponto4) > 0:
  print("Esse ponto é classificado como classe w1")
else:
  print("Esse ponto é classificado como classe w2")
# Out:
# Esse ponto é classificado como classe w1

# %% [markdown]
# **QUESTÃO 6**: Apresente um estudo sobre as seguintes medidas de desempenho de classificadores de padrões: Acurácia, Precisão e F-Score.

# %% [markdown]
# **RESPOSTA**:
#
# **Acurácia**: é uma métrica de avaliação de modelos de inteligência artificial em problemas de classificação. Ou seja, a acurácia é um valor numérico resultante da razão entre as previsões acertadas pelo modelo e o número total de previsão. Assim, podemos escrever a fórmula:
#
# $$𝐴𝑐𝑢𝑟á𝑐𝑖𝑎 = \frac{𝑁ú𝑚𝑒𝑟𝑜\space 𝑑𝑒 \space 𝑝𝑟𝑒𝑣𝑖𝑠õ𝑒𝑠 \space 𝑐𝑜𝑟𝑟𝑒𝑡𝑎}{𝑁ú𝑚𝑒𝑟𝑜 \space 𝑡𝑜𝑡𝑎𝑙 \space 𝑑𝑒 \space 𝑝𝑟𝑒𝑣𝑖𝑠õ𝑒𝑠}$$
#
# Para um problema de classificação binária, na qual temos duas classes, podemos calcular a acurácia da seguinte forma:
#
# $$𝐴𝑐𝑢𝑟á𝑐𝑖𝑎 = \frac{𝑉𝑃 + 𝑉𝑁
# }{𝑉𝑃 + 𝑉𝑁 + 𝐹𝑃 + 𝐹N},$$
#
# onde VP = Verdadeiro positivo, VN = Verdadeiro negativo, FP = Falso positivo e FN = Falso negativo. Apesar da demonstração ser para um problema de classificação de duas classes, esta métrica pode ser utilizada para problemas de classificação multiclasses.
#
# **Precisão**: é uma métrica calculada a partir da razão entre a quantidade de verdadeiros positivos sobre o número total de classificações positivas, isto é, a soma de verdadeiros positivos e falso positivos. Assim, quanto mais previsões verdadeiras corretas, mais a precisão do modelo se aproxima de 1, ao passo que se aproxima de 0 à medida que o número de falso positivos tende a aumentar. Assim, podemos escrever a equação da precisão da seguinte maneira:
#
# $$Precisão = \frac{𝑉𝑃}{𝑉𝑃 + 𝐹𝑃}$$
#
# Uma situação em que essa métrica é de suma importância é na realização de
# empréstimos dado o histórico de um mutuário, pois caso o modelo classifique a pessoa como sendo boa pagadora, sendo que na verdade ela é mau pagadora (falso positivo), o modelo irá fazer com que os investidores percam dinheiro.
#
# **F-Score**: É uma métrica utilizada para a avaliação de modelos de classificação e é definida como a média harmônica entre a precisão e o recall. Também conhecido como sensibilidade, o recall é outra métrica de avaliação de modelos que é definida pela razão entre os verdadeiros positivos e a soma dos verdadeiros positivos e falso negativos. As fórmulas do recall e do F-Score são definidas pela equação abaixo:
#
# $$Recall = \frac{𝑉𝑃}{𝑉𝑃 + 𝐹N}$$
#
# $$F_{\beta} = (1 + \beta^2).\frac{𝑃𝑟𝑒𝑐𝑖𝑠ã𝑜.𝑅𝑒𝑐𝑎𝑙l}{(\beta^2.𝑝𝑟𝑒𝑐𝑖𝑠ã𝑜) + 𝑟𝑒𝑐𝑎𝑙𝑙}$$
#
# Os mais comuns são: o F1-Score fornece pesos iguais para o precisão e para o recall, o F2-Score que fornece um peso maior para o recall e o F0.5-Score que fornece um peso maior para a precisão. Em relação às suas aplicações, o F-Score é comumente utilizado em sistemas que utilizam mecanismos de busca e processamento de linguagem natural.

# %% [markdown]
# **TRABALHO 1**: Pesquise e apresente um trabalho sobre o algoritmo Naïve-Bayes para a detecção de Spam em mensagens de email ou para classificar páginas de texto como interessante ou não interessante com base em um tema de interesse (esporte, política, ...etc.) presente nas palavras que aparecem nas páginas.

# %% [markdown]
# **TRABALHO 2**: Pesquise e apresente um trabalho sobre Random Forest com uma aplicação de livre escolha
#
# O desenvolvimento do trabalho pode ser encontrado no meu repositório no [GitHub](https://github.com/jsleocadio/Artificial-Intelligence/blob/main/Random%20Forest/Random_Forest_Paperwork.ipynb).
